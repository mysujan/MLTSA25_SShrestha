# %% [markdown]
# <a href="https://colab.research.google.com/github/mysujan/FDSFE_SShrestha/blob/main/inclasscode/second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::")
# Out:
# <ipython-input-12-ebcd1228fb3b>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::")
#          1                    Toy Story (1995)   Animation|Children's|Comedy
# 0        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1        3             Grumpier Old Men (1995)                Comedy|Romance
# 2        4            Waiting to Exhale (1995)                  Comedy|Drama
# 3        5  Father of the Bride Part II (1995)                        Comedy
# 4        6                         Heat (1995)         Action|Crime|Thriller
# ...    ...                                 ...                           ...
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=False)
# Out:
# <ipython-input-13-c17fed5bd24c>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=False)
#          1                    Toy Story (1995)   Animation|Children's|Comedy
# 0        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1        3             Grumpier Old Men (1995)                Comedy|Romance
# 2        4            Waiting to Exhale (1995)                  Comedy|Drama
# 3        5  Father of the Bride Part II (1995)                        Comedy
# 4        6                         Heat (1995)         Action|Crime|Thriller
# ...    ...                                 ...                           ...
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=0)
# Out:
# <ipython-input-14-f80733f9f3d6>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=0)
#                         Toy Story (1995)   Animation|Children's|Comedy
# 1
# 2                         Jumanji (1995)  Adventure|Children's|Fantasy
# 3                Grumpier Old Men (1995)                Comedy|Romance
# 4               Waiting to Exhale (1995)                  Comedy|Drama
# 5     Father of the Bride Part II (1995)                        Comedy
# 6                            Heat (1995)         Action|Crime|Thriller
# ...                                  ...                           ...
# 3948             Meet the Parents (2000)                        Comedy
# ...

# %%
pd.read_csv? #gives the detail
# Out:
#   File "<ipython-input-15-f922e6be0577>", line 1
#     pd.read_csv? #gives the detail
#                ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=0, names = ["names","genre"])

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=0, names = ["names","genre"])
# Out:
# <ipython-input-18-005efaa15d95>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_csv("https://raw.githubusercontent.com/fedhere/PyBOOT/refs/heads/master/data/movies.dat", delimiter="::", index_col=0, names = ["names","genre"])

# %%
movies.head()

# %%
movies.tail()

# %%
movies.columns

# %%
movies.loc[:,"names"]

# %%
movies.iloc[:,0]

# %%
movies.loc[1,"names"]

# %%
movies.loc[1,"names"].split()

# %%
movies.loc[1,"names"].split("(")[1]

# %%
int(movies.loc[1,"names"].split("(")[1].strip(")"))

# %%
def getyear(name):
  return int(names.split("(")[1].strip(")"))
movies["Year"] = movies["names"].map(getyear)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-6bd948d3aaf5> in <cell line: 0>()
#       1 def getyear(name):
# ...
